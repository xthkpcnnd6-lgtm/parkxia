# %% [markdown]
# ![Gemini_Generated_Image_ef8yblef8yblef8y.png](attachment:Gemini_Generated_Image_ef8yblef8yblef8y.png)

# %% [markdown]
# ![파이썬기초 핵심요약.png](<attachment:파이썬기초 핵심요약.png>)

# %% [markdown]
# ![데이터베이스 핵심요약.png](<attachment:데이터베이스 핵심요약.png>)

# %% [markdown]
# ![데이터분석 핵심요약.png](<attachment:데이터분석 핵심요약.png>)

# %% [markdown]
# ![머신&딥러닝 핵심요약.png](<attachment:머신&딥러닝 핵심요약.png>)

# %% [markdown]
# ## *추가 학습이 필요한 것들*

# %% [markdown]
# <span style="font-family: 'Gungsuh', '바탕체'; font-size: 1.6em; font-style: italic;">LLM과 LMM</span>
#
# <span style="font-family: 'Gungsuh', '바탕체'; font-size: 1.6em; font-style: italic;">웹 프레임워크</span>
#
# <span style="font-family: 'Gungsuh', '바탕체'; font-size: 1.6em; font-style: italic;">MLOps, 클라우드</span>
#
# <span style="font-family: 'Gungsuh', '바탕체'; font-size: 1.6em; font-style: italic;">심화 통계/ 수학</span>
